# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('dark_background')

# %%
df=pd.read_csv('C:\\Users\\pythonvs\\webscrapping\\amazon.csv')
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
p=pd.DataFrame(df)
p.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
p['rating']
# Out:
# 0       4.2
# 1       4.0
# 2       3.9
# 3       4.2
# 4       4.2
#        ...
# 1460      4
# 1461    4.1
# 1462    3.6
# 1463      4
# 1464    4.3
# Name: rating, Length: 1465, dtype: object

# %%
p['rating'].value_counts(ascending=True)
# Out:
# rating
# 2.9      1
# 3        1
# 2        1
# |        1
# 2.3      1
# 2.6      1
# 2.8      2
# 3.2      2
# 4.8      3
# 3.0      3
# 5.0      3
# 3.1      4
# 4.7      6
# 3.4     10
# 3.3     16
# 4.6     17
# 3.5     26
# 3.6     35
# 3.7     42
# 4       52
# 4.5     75
# 3.8     86
# 4.4    123
# 3.9    123
# 4.0    129
# 4.2    228
# 4.3    230
# 4.1    244
# Name: count, dtype: int64

# %%
p1=df[df['rating'].str.contains('5.0')]
p1
# Out:
#      product_id                                       product_name  \
# 174  B0BP7XLX48  Syncwire LTG to USB Cable for Fast Charging Co...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# 775  B09ZHCJDP1  Amazon Basics Wireless Mouse | 2.4 GHz Connect...
#
#                                               category discounted_price  \
# 174  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 324  Computers&Accessories|Accessories&Peripherals|...             ₹249
# 775  Computers&Accessories|Accessories&Peripherals|...             ₹499
#
#     actual_price discount_percentage rating rating_count  \
# 174       ₹1,999                 80%    5.0            5
# 324         ₹999                 75%    5.0          NaN
# 775       ₹1,000                 50%    5.0           23
#
#                                          about_product  \
# 174  This sturdy and durable cable made of tpe and ...
# 324  💎[The Fastest Charge] - This iPhone USB C cabl...
# ...

# %%
p1['product_name']
# Out:
# 174    Syncwire LTG to USB Cable for Fast Charging Co...
# 324    REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# 775    Amazon Basics Wireless Mouse | 2.4 GHz Connect...
# Name: product_name, dtype: object

# %%
p2=p1.set_index('product_id')
p2
# Out:
#                                                  product_name  \
# product_id
# B0BP7XLX48  Syncwire LTG to USB Cable for Fast Charging Co...
# B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# B09ZHCJDP1  Amazon Basics Wireless Mouse | 2.4 GHz Connect...
#
#                                                      category  \
# product_id
# B0BP7XLX48  Computers&Accessories|Accessories&Peripherals|...
# B0BQRJ3C47  Computers&Accessories|Accessories&Peripherals|...
# B09ZHCJDP1  Computers&Accessories|Accessories&Peripherals|...
#
#            discounted_price actual_price discount_percentage rating  \
# product_id
# B0BP7XLX48             ₹399       ₹1,999                 80%    5.0
# B0BQRJ3C47             ₹249         ₹999                 75%    5.0
# B09ZHCJDP1             ₹499       ₹1,000                 50%    5.0
#
#            rating_count                                      about_product  \
# product_id
# ...

# %%
p2=p1.drop(['category','about_product','review_id', 'review_title',
       'review_content', 'img_link', 'product_link','discount_percentage','user_id','user_name'],axis=1)
p2.head()
# Out:
#      product_id                                       product_name  \
# 174  B0BP7XLX48  Syncwire LTG to USB Cable for Fast Charging Co...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# 775  B09ZHCJDP1  Amazon Basics Wireless Mouse | 2.4 GHz Connect...
#
#     discounted_price actual_price rating rating_count
# 174             ₹399       ₹1,999    5.0            5
# 324             ₹249         ₹999    5.0          NaN
# 775             ₹499       ₹1,000    5.0           23

# %%
p2.filter(items=['product_name','rating','discounted_price','actual_price'])
# Out:
#                                           product_name rating  \
# 174  Syncwire LTG to USB Cable for Fast Charging Co...    5.0
# 324  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...    5.0
# 775  Amazon Basics Wireless Mouse | 2.4 GHz Connect...    5.0
#
#     discounted_price actual_price
# 174             ₹399       ₹1,999
# 324             ₹249         ₹999
# 775             ₹499       ₹1,000

# %%
#p2['actual_price'] = p2['actual_price'].replace("₹", "").replace(",", "").replace(".", "")
#p2['actual_price'] = p2['actual_price'].astype(int)

# %%
#p2['discounted_price'] = p2['discounted_price'].astype(int)

#p2['price_difference']=p2['discounted_price']-df['actual_price']

# %%
#p2.filter(items=['product_name','rating','discounted_price','actual_price'])

# %%
p2['discounted_price'] = p2['discounted_price'].str.replace("₹",'')
p2['discounted_price'] = p2['discounted_price'].str.replace(",",'')
p2['discounted_price'] = p2['discounted_price'].astype('float64')
p2['actual_price'] = p2['actual_price'].str.replace("₹",'')
p2['actual_price'] = p2['actual_price'].str.replace(",",'')
p2['actual_price'] = p2['actual_price'].astype('float64')
p2
# Out:
#      product_id                                       product_name  \
# 174  B0BP7XLX48  Syncwire LTG to USB Cable for Fast Charging Co...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# 775  B09ZHCJDP1  Amazon Basics Wireless Mouse | 2.4 GHz Connect...
#
#      discounted_price  actual_price rating rating_count
# 174             399.0        1999.0    5.0            5
# 324             249.0         999.0    5.0          NaN
# 775             499.0        1000.0    5.0           23

# %%
p2.filter(items=['product_name','rating','discounted_price','actual_price'])
# Out:
#                                           product_name rating  \
# 174  Syncwire LTG to USB Cable for Fast Charging Co...    5.0
# 324  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...    5.0
# 775  Amazon Basics Wireless Mouse | 2.4 GHz Connect...    5.0
#
#      discounted_price  actual_price
# 174             399.0        1999.0
# 324             249.0         999.0
# 775             499.0        1000.0

# %%
p2['price_difference']=p2['actual_price']-p2['discounted_price']
p2
# Out:
#      product_id                                       product_name  \
# 174  B0BP7XLX48  Syncwire LTG to USB Cable for Fast Charging Co...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# 775  B09ZHCJDP1  Amazon Basics Wireless Mouse | 2.4 GHz Connect...
#
#      discounted_price  actual_price rating rating_count  price_difference
# 174             399.0        1999.0    5.0            5            1600.0
# 324             249.0         999.0    5.0          NaN             750.0
# 775             499.0        1000.0    5.0           23             501.0

# %%
df.loc[324]
# Out:
# product_id                                                    B0BQRJ3C47
# product_name           REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# category               Computers&Accessories|Accessories&Peripherals|...
# discounted_price                                                    ₹249
# actual_price                                                        ₹999
# discount_percentage                                                  75%
# rating                                                               5.0
# rating_count                                                         NaN
# about_product          💎[The Fastest Charge] - This iPhone USB C cabl...
# user_id                                     AGJC5O5H5BBXWUV7WRIEIOOR3TVQ
# user_name                                                    Abdul Gafur
# review_id                                                  RQXD5SAMMPC6L
# review_title                                             Awesome Product
# ...

# %%
df.loc[174]
# Out:
# product_id                                                    B0BP7XLX48
# product_name           Syncwire LTG to USB Cable for Fast Charging Co...
# category               Computers&Accessories|Accessories&Peripherals|...
# discounted_price                                                    ₹399
# actual_price                                                      ₹1,999
# discount_percentage                                                  80%
# rating                                                               5.0
# rating_count                                                           5
# about_product          This sturdy and durable cable made of tpe and ...
# user_id                AF7EOXYL5K36BDP6PXF6K2TL5TPA,AEN7NV2P5WNHM7EXC...
# user_name              Amazon Customer,kamal sahota,Pankaj,luvsmplcty...
# review_id              R1L2JNO4Y3BHYF,R2346F22YLZ9IG,R3A4GAQTCPE5U7,R...
# review_title           Good,Superb quality,Good products  nice one,Wo...
# ...

# %%
p2.fillna(1)
# Out:
#      product_id                                       product_name  \
# 174  B0BP7XLX48  Syncwire LTG to USB Cable for Fast Charging Co...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# 775  B09ZHCJDP1  Amazon Basics Wireless Mouse | 2.4 GHz Connect...
#
#      discounted_price  actual_price rating rating_count  price_difference
# 174             399.0        1999.0    5.0            5            1600.0
# 324             249.0         999.0    5.0            1             750.0
# 775             499.0        1000.0    5.0           23             501.0

# %%
plt.figure(figsize=(8,5))
sns.lineplot(x=p2['discounted_price'],y=p2['actual_price'])
plt.scatter(p2['discounted_price'], p2['actual_price'], color='green', s=69, alpha=1)
plt.xticks(rotation='vertical',size=8)
plt.show()
